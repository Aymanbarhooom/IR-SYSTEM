# %%
import json
import os

import matplotlib.pyplot as plt

from services.evaluator import Evaluator

# %%
import json
import os

import matplotlib.pyplot as plt

from services.evaluator import Evaluator

MODEL = "tfidf"
evaluator = Evaluator(
    model_type=MODEL
)

results = evaluator.evaluate()

results
print("\nEvaluation Results\n")

for metric, value in results.items():
    print(f"{metric}: {value}")
# Out:
# 🔄 Building index for tfidf...
# Loading processed documents...
# Building TF-IDF matrix...
# Indexed 369721 documents
# [100/1444] 89.6 sec
# [200/1444] 169.5 sec
# [300/1444] 246.4 sec
# [400/1444] 323.2 sec
# [500/1444] 403.6 sec
# [600/1444] 494.9 sec
# [700/1444] 574.8 sec
# [800/1444] 656.8 sec
# [900/1444] 734.7 sec
# [1000/1444] 814.2 sec
# [1100/1444] 894.0 sec
# [1200/1444] 974.0 sec
# [1300/1444] 1052.9 sec
# [1400/1444] 1131.1 sec
#
# Evaluation Results
#
# model: tfidf
# queries: 1444
# precision@10: 0.18628808864265928
# recall@10: 0.17012573825637942
# MAP@10: 0.14874782605793932
# nDCG@10: 0.31017483669103574
# time (sec): 1165.55
# queries/sec: 1.24

# %%
os.makedirs("../results", exist_ok=True)

filename = f"../results/{MODEL}_results.json"

with open(
    filename,
    "w",
    encoding="utf-8"
) as f:

    json.dump(
        results,
        f,
        indent=4
    )

print(f"\nSaved to {filename}")
# Out:
# Saved to ../results/tfidf_results.json

# %%
metrics = [
    f"precision@10",
    f"recall@10",
    f"MAP@10",
    f"nDCG@10"
]

values = [
    results[m]
    for m in metrics
]

plt.figure(figsize=(8,5))

plt.bar(
    metrics,
    values
)

plt.ylim(0,1)

plt.title(
    f"{MODEL.upper()} Evaluation"
)

plt.ylabel("Score")

plt.grid(axis="y")

plt.show()

# %%
plt.savefig(
    f"../results/{MODEL}.png",
    dpi=300,
    bbox_inches="tight"
)
