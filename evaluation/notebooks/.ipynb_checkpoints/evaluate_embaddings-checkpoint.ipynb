# %%
import json
import os
import sys

PROJECT_ROOT = os.path.abspath("../..")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(PROJECT_ROOT)

from services.evaluator import Evaluator

MODEL = "embedding"
evaluator = Evaluator(
    model_type=MODEL
)

results = evaluator.evaluate()

results
print("\nEvaluation Results\n")

for metric, value in results.items():
    print(f"{metric}: {value}")
# Out:
# C:\IR_SYSTEM
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# 📂 Loading existing embeddings...
# ✅ Loaded 10000 document embeddings.
# 🔄 Building index for embedding...
#
# 📂 Loading existing embeddings...
# ✅ Loaded 10000 document embeddings.
# [100/1444] 2.5 sec
# [200/1444] 5.0 sec
# [300/1444] 7.4 sec
# [400/1444] 9.7 sec
# [500/1444] 12.1 sec
# [600/1444] 14.7 sec
# [700/1444] 17.2 sec
# [800/1444] 19.7 sec
# [900/1444] 22.4 sec
# [1000/1444] 25.2 sec
# [1100/1444] 28.0 sec
# [1200/1444] 30.7 sec
# [1300/1444] 33.7 sec
# [1400/1444] 36.5 sec
#
# Evaluation Results
#
# model: embedding
# queries: 1444
# precision@10: 0.02008310249307479
# recall@10: 0.010443236355871306
# MAP@10: 0.012751959394099283
# nDCG@10: 0.026888333470159623
# time (sec): 37.56
# queries/sec: 38.44

# %%
os.makedirs("../results", exist_ok=True)

filename = f"../results/{MODEL}_results.json"

with open(
    filename,
    "w",
    encoding="utf-8"
) as f:

    json.dump(
        results,
        f,
        indent=4
    )

print(f"\nSaved to {filename}")
# Out:
# Saved to ../results/embedding_results.json

# %%
import matplotlib.pyplot as plt

metrics = [
    f"precision@10",
    f"recall@10",
    f"MAP@10",
    f"nDCG@10"
]

values = [
    results[m]
    for m in metrics
]

plt.figure(figsize=(8,5))

plt.bar(
    metrics,
    values
)

plt.ylim(0,1)

plt.title(
    f"{MODEL.upper()} Evaluation"
)

plt.ylabel("Score")

plt.grid(axis="y")

plt.show()

# %%
plt.savefig(
    f"../results/{MODEL}.png",
    dpi=300,
    bbox_inches="tight"
)
